# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
import citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
weather_api_key
# Out:
# '5c27e011cae1595240ba661115f51b08'

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 631

# %%
cities
# Out:
# ['kichera',
#  'chuy',
#  'vestmannaeyjar',
#  'kapaa',
#  'thompson',
#  'qaqortoq',
#  'jamestown',
#  'qaanaaq',
#  'saint-philippe',
#  'bani',
#  'tuktoyaktuk',
#  'san cristobal',
#  'saint-paul',
#  'ushuaia',
#  'kapit',
#  'albany',
#  'catamarca',
#  'hermanus',
#  'pedernales',
#  'busselton',
#  'punta arenas',
#  'sibolga',
#  'avarua',
#  'nantucket',
#  'gornopravdinsk',
#  'basco',
#  'cape town',
#  'haibowan',
#  'lokosovo',
#  'hilo',
#  'avera',
#  'umzimvubu',
#  'mataura',
#  'coihaique',
#  'pacific grove',
#  'sao joao da barra',
#  'new norfolk',
#  'bluff',
#  'rikitea',
#  'vaini',
#  'kutum',
#  'saskylakh',
#  'carnarvon',
#  'kabare',
#  'havoysund',
#  'amderma',
#  'taltal',
#  'port alfred',
#  'taolanaro',
#  'somerville',
#  'zigong',
#  'tasiilaq',
#  'gornyy',
#  'hithadhoo',
#  'butaritari',
#  'san juan ixcoy',
#  'port blair',
#  'port elizabeth',
#  'timiryazevskoye',
#  'bredasdorp',
#  'chumikan',
#  'atuona',
#  'valverde del camino',
#  'bambous virieux',
#  'yellowknife',
#  'kadirli',
#  'lavrentiya',
#  'norsup',
#  'torbay',
#  'fram',
#  'kavieng',
#  'dingle',
#  'attawapiskat',
#  'nikolskoye',
#  'kanganpur',
#  'lorengau',
#  'shibetsu',
#  'axim',
#  'lata',
#  'progreso',
#  'manta',
#  'lebu',
#  'akdepe',
#  'changji',
#  'tsihombe',
#  'praia',
#  'tiksi',
#  'pisco',
#  'annur',
#  'nanortalik',
#  'chokurdakh',
#  'sao filipe',
#  'la ronge',
#  'petauke',
#  'tsiroanomandidy',
#  'grand river south east',
#  'barrow',
#  'santa rosalia',
#  'batemans bay',
#  'bengkulu',
#  'marystown',
#  'east london',
#  'san quintin',
#  'todos santos',
#  'hobart',
#  'jalu',
#  'san joaquin',
#  'wanning',
#  'port hedland',
#  'vao',
#  'khao yoi',
#  'bandarbeyla',
#  'souillac',
#  'moose factory',
#  'rawson',
#  'mount isa',
#  'bengkalis',
#  'katherine',
#  'janakkala',
#  'te anau',
#  'totness',
#  'bukama',
#  'mahebourg',
#  'addi ugri',
#  'mehamn',
#  'santa isabel do rio negro',
#  'belushya guba',
#  'provideniya',
#  'codrington',
#  'cherskiy',
#  'srednekolymsk',
#  'faya',
#  'longyearbyen',
#  'tatarskaya kargala',
#  'bintulu',
#  'victoria',
#  'koshki',
#  'camacha',
#  'dikson',
#  'talaya',
#  'yenagoa',
#  'georgetown',
#  'port hueneme',
#  'play cu',
#  'gimli',
#  'platanos',
#  'severo-kurilsk',
#  'ilebo',
#  'ahuimanu',
#  'sentyabrskiy',
#  'mogadishu',
#  'katsuura',
#  'asau',
#  'ponta do sol',
#  'aklavik',
#  'kodiak',
#  'eucaliptus',
#  'saleaula',
#  'tshela',
#  'castro',
#  'bima',
#  'arraial do cabo',
#  'dukat',
#  'sechura',
#  'daru',
#  'egvekinot',
#  'port lincoln',
#  'kommunisticheskiy',
#  'comodoro rivadavia',
#  'kahului',
#  'fillmore',
#  'zhigansk',
#  'mezen',
#  'belyy yar',
#  'ghansor',
#  'shenzhen',
#  'marcona',
#  'bafq',
#  'rosario do sul',
#  'solnechnyy',
#  'faanui',
#  'san patricio',
#  'palabuhanratu',
#  'vardo',
#  'sehithwa',
#  'tuatapere',
#  'ondorhaan',
#  'san ramon',
#  'puerto ayora',
#  'illoqqortoormiut',
#  'rabo de peixe',
#  'villamar',
#  'santa vitoria do palmar',
#  'yirol',
#  'mahanoro',
#  'am timan',
#  'gazli',
#  'minab',
#  'abashiri',
#  'yeppoon',
#  'barentsburg',
#  'tigil',
#  'tanete',
#  'sorvag',
#  'tazovskiy',
#  'lompoc',
#  'agirish',
#  'halalo',
#  'vaitupu',
#  'tautira',
#  'preobrazheniye',
#  'karratha',
#  'nelson bay',
#  'palu',
#  'acajutla',
#  'namatanai',
#  'gizo',
#  'nizhneyansk',
#  'lashio',
#  'murray bridge',
#  'jian',
#  'pitimbu',
#  'geraldton',
#  'xuddur',
#  'esperance',
#  'grand island',
#  'xining',
#  'hofn',
#  'key largo',
#  'takoradi',
#  'haines junction',
#  'safaga',
#  'kaberamaido',
#  'qasigiannguit',
#  'mayo',
#  'bethel',
#  'bathsheba',
#  'goya',
#  'sao luiz gonzaga',
#  'pingliang',
#  'bartica',
#  'yerbogachen',
#  'araguatins',
#  'mar del plata',
#  'mys shmidta',
#  'sapao',
#  'airai',
#  'los llanos de aridane',
#  'ocampo',
#  'vanimo',
#  'karlovac',
#  'khatanga',
#  'sulangan',
#  'tessalit',
#  'puerto leguizamo',
#  'edd',
#  'suntar',
#  'monkey bay',
#  'lensk',
#  'vargashi',
#  'wellington',
#  'samarai',
#  'vestmanna',
#  'narsaq',
#  'giyani',
#  'alofi',
#  'pedasi',
#  'tuy hoa',
#  'kiruna',
#  'sokolo',
#  'rungata',
#  'tilichiki',
#  'zyryanka',
#  'saint-augustin',
#  'sheboygan',
#  'leningradskiy',
#  'tura',
#  'seoul',
#  'kirakira',
#  'cayenne',
#  'pevek',
#  'vostok',
#  'tateyama',
#  'hualmay',
#  'harper',
#  'usinsk',
#  'ligayan',
#  'isla mujeres',
#  'rapid valley',
#  'heishan',
#  'straumen',
#  'superior',
#  'namibe',
#  'graaff-reinet',
#  'narino',
#  'colombo',
#  'kinanah',
#  'tolbazy',
#  'ziro',
#  'port moresby',
#  'jega',
#  'ostersund',
#  'krasnoselkup',
#  'cholan',
#  'grand-santi',
#  'sitka',
#  'mbeya',
#  'tiznit',
#  'port-gentil',
#  'lisala',
#  'guozhen',
#  'labutta',
#  'cabo san lucas',
#  'santiago del estero',
#  'kaitangata',
#  'nioro',
#  'nago',
#  'grass valley',
#  'lagoa',
#  'redmond',
#  'ribeira grande',
#  'kloulklubed',
#  'luderitz',
#  'bembereke',
#  'maloshuyka',
#  'ondangwa',
#  'nyurba',
#  'clyde river',
#  'baoqing',
#  'mabaruma',
#  'talara',
#  'champerico',
#  'riyadh',
#  'cotoca',
#  'acandi',
#  'tomigusuku',
#  'new castle',
#  'bourail',
#  'alihe',
#  'kidal',
#  'rawannawi',
#  'mount gambier',
#  'iqaluit',
#  'caravelas',
#  'dubbo',
#  'pierrelatte',
#  'cruzilia',
#  'erzin',
#  'afsin',
#  'linkoping',
#  'ulladulla',
#  'reconquista',
#  'alma',
#  'constitucion',
#  'cidreira',
#  'upington',
#  'barcelos',
#  'burnie',
#  'mayumba',
#  'raga',
#  'tumannyy',
#  'camana',
#  'ancud',
#  'umm kaddadah',
#  'arua',
#  'boulder city',
#  'carutapera',
#  'dali',
#  'sakaiminato',
#  'inuvik',
#  'stellenbosch',
#  'fredericton',
#  'haysville',
#  'jieshi',
#  'mariinsk',
#  'puerto carreno',
#  'wattegama',
#  'saint george',
#  'ayagoz',
#  'sinnamary',
#  'durban',
#  'ruwi',
#  'villefranche-de-rouergue',
#  'zhengjiatun',
#  'mudgee',
#  'hasaki',
#  'imst',
#  'tolaga bay',
#  'semey',
#  'sidrolandia',
#  'kyzyl-suu',
#  'gwadar',
#  'flinders',
#  'taseyevo',
#  'nizhniy kuranakh',
#  'bemidji',
#  'tecoanapa',
#  'kedrovyy',
#  'yuzhno-yeniseyskiy',
#  'mitu',
#  'talnakh',
#  'majene',
#  'ambilobe',
#  'sombrio',
#  'paracuru',
#  'san-pedro',
#  'yarim',
#  'ha giang',
#  'wyndham',
#  'jutai',
#  'exokhi',
#  'lovozero',
#  'isabela',
#  'barawe',
#  'yablonovo',
#  'saldanha',
#  'upernavik',
#  'aksarka',
#  'maneromango',
#  'beringovskiy',
#  'fortuna',
#  'shingu',
#  'tunduru',
#  'kazalinsk',
#  'thinadhoo',
#  'pervoye maya',
#  'gulu',
#  'ekimchan',
#  'bonthe',
#  'ndioum',
#  'north bend',
#  'opuwo',
#  'tabou',
#  'dunmore town',
#  'kamenskoye',
#  'henties bay',
#  'saint-pierre',
#  'oyon',
#  'vanavara',
#  'kegayli',
#  'norman wells',
#  'broken hill',
#  'jiayuguan',
#  'ormond beach',
#  'rafaela',
#  'kharp',
#  'chase',
#  'aromashevo',
#  'voh',
#  'pakokku',
#  'gazanjyk',
#  'pangnirtung',
#  'inta',
#  'mango',
#  'maniitsoq',
#  'marfino',
#  'neuquen',
#  'san bartolome de tirajana',
#  'moindou',
#  'micheweni',
#  'darhan',
#  'moron',
#  'bitung',
#  'bulgan',
#  'gashua',
#  'portland',
#  'viedma',
#  'college',
#  'monrovia',
#  'aykhal',
#  'umm lajj',
#  'ahipara',
#  'halifax',
#  'shaunavon',
#  'kaeo',
#  'sur',
#  'lakefield',
#  'bargal',
#  'sarangani',
#  'puerto lempira',
#  'srivardhan',
#  'turukhansk',
#  'teacapan',
#  'careiro da varzea',
#  'luena',
#  'mahadday weyne',
#  'ukiah',
#  'cockburn town',
#  'chute-aux-outardes',
#  'hervey bay',
#  'kavaratti',
#  'sargatskoye',
#  'zharkent',
#  'belaya gora',
#  'vila franca do campo',
#  'brokopondo',
#  'san angelo',
#  'jacareacanga',
#  'sabana grande de boya',
#  'kenora',
#  'hambantota',
#  'dhidhdhoo',
#  'mugur-aksy',
#  'fort saint john',
#  'finschhafen',
#  'kindersley',
#  'korem',
#  'morki',
#  'novyy urengoy',
#  'meyungs',
#  'fort-de-france',
#  'carmen',
#  'paamiut',
#  'batticaloa',
#  'villarrica',
#  'milkovo',
#  'kintinku',
#  'istisu',
#  'tucurui',
#  'clovis',
#  'sesheke',
#  'maridi',
#  'ngukurr',
#  'keshod',
#  'salinas',
#  'omboue',
#  'amapa',
#  'mocambique',
#  'kruisfontein',
#  'hammerfest',
#  'khorramshahr',
#  'menongue',
#  'goderich',
#  'aasiaat',
#  'tierralta',
#  'tam ky',
#  'port macquarie',
#  'tidore',
#  'alcacer do sal',
#  'san juan',
#  'el faiyum',
#  'flin flon',
#  'bressuire',
#  'whitehorse',
#  'pangai',
#  'gubskaya',
#  'raudeberg',
#  'sao mateus do maranhao',
#  'pinawa',
#  'nagai',
#  'libreville',
#  'girvan',
#  'martinsville',
#  'poum',
#  'nome',
#  'kourou',
#  'bud',
#  'lubao',
#  'nebbi',
#  'fort nelson',
#  'broome',
#  'zhangzhou',
#  'cao bang',
#  'kolosovka',
#  'trimbak',
#  'chengde',
#  'rio tuba',
#  'santa maria',
#  'richmond',
#  'maputo',
#  'plettenberg bay',
#  'svay rieng',
#  'banff',
#  'kaili',
#  'sakakah',
#  'onega',
#  'margate',
#  'beira',
#  'jackson',
#  'la romana',
#  'hobyo',
#  'toropets',
#  'taree',
#  'kushima',
#  'kalmunai',
#  'ostrovnoy',
#  'roma',
#  'lethem',
#  'mackay',
#  'altay',
#  'leeton',
#  'panama city',
#  'somerset east',
#  'samusu',
#  'zunyi',
#  'itoman',
#  'aksu',
#  'antofagasta',
#  'yeniseysk',
#  'hirado',
#  'paita',
#  'lagos',
#  'oktyabrskiy',
#  'kasongo-lunda',
#  'makakilo city',
#  'matara',
#  'wajir',
#  'waitati',
#  'hanamaki',
#  'chagda',
#  'gien',
#  'lakes entrance',
#  'nuuk',
#  'the valley',
#  'mwanza',
#  'grand gaube',
#  'konstantinovskiy',
#  'boissevain']

# %% [markdown]
# ---

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"
print(url + "&q=san francisco")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&appid=5c27e011cae1595240ba661115f51b08&q=san francisco

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | bandarbeyla
# Processing Record 3 of Set 1 | georgetown
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | chokurdakh
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | sobolevo
# Processing Record 8 of Set 1 | ixtapa
# Processing Record 9 of Set 1 | arlit
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 13 of Set 1 | kalmunai
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | jiroft
# City not found. Skipping...
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | cherskiy
# Processing Record 20 of Set 1 | coihaique
# Processing Record 21 of Set 1 | lompoc
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | esik
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | mountain home
# Processing Record 26 of Set 1 | carnarvon
# Processing Record 27 of Set 1 | vagur
# Processing Record 28 of Set 1 | sandwich
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | lebu
# Processing Record 33 of Set 1 | salalah
# Processing Record 34 of Set 1 | haines junction
# Processing Record 35 of Set 1 | bengkulu
# Processing Record 36 of Set 1 | hovd
# Processing Record 37 of Set 1 | tiznit
# Processing Record 38 of Set 1 | wilmington
# Processing Record 39 of Set 1 | touros
# Processing Record 40 of Set 1 | duz
# City not found. Skipping...
# Processing Record 41 of Set 1 | bjala
# City not found. Skipping...
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | nalut
# Processing Record 44 of Set 1 | dharchula
# Processing Record 45 of Set 1 | morehead
# Processing Record 46 of Set 1 | sayyan
# Processing Record 47 of Set 1 | ecuandureo
# Processing Record 48 of Set 1 | kaitangata
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | qaqortoq
# Processing Record 0 of Set 2 | zhigansk
# Processing Record 1 of Set 2 | cap malheureux
# Processing Record 2 of Set 2 | mana
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | dasoguz
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | nauta
# Processing Record 8 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 2 | guerrero negro
# Processing Record 13 of Set 2 | kendari
# Processing Record 14 of Set 2 | shahrud
# Processing Record 15 of Set 2 | paraiso
# Processing Record 16 of Set 2 | safranbolu
# Processing Record 17 of Set 2 | kanniyakumari
# Processing Record 18 of Set 2 | nouadhibou
# Processing Record 19 of Set 2 | thanh hoa
# Processing Record 20 of Set 2 | saint-augustin
# Processing Record 21 of Set 2 | codrington
# Processing Record 22 of Set 2 | bereda
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | daru
# Processing Record 25 of Set 2 | chase
# Processing Record 26 of Set 2 | san carlos de bariloche
# Processing Record 27 of Set 2 | tougan
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | hwange
# Processing Record 30 of Set 2 | geraldton
# Processing Record 31 of Set 2 | chapais
# Processing Record 32 of Set 2 | lorengau
# Processing Record 33 of Set 2 | ntoum
# Processing Record 34 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 2 | samarai
# Processing Record 36 of Set 2 | bambous virieux
# Processing Record 37 of Set 2 | port pirie
# Processing Record 38 of Set 2 | hualmay
# Processing Record 39 of Set 2 | svetlogorsk
# Processing Record 40 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 41 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 2 | osorno
# Processing Record 43 of Set 2 | vila velha
# Processing Record 44 of Set 2 | juneau
# Processing Record 45 of Set 2 | terra santa
# Processing Record 46 of Set 2 | saldanha
# Processing Record 47 of Set 2 | avera
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | dunaujvaros
# Processing Record 0 of Set 3 | tadine
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | elko
# Processing Record 3 of Set 3 | mahebourg
# Processing Record 4 of Set 3 | itoman
# Processing Record 5 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 6 of Set 3 | williams lake
# Processing Record 7 of Set 3 | conde
# Processing Record 8 of Set 3 | tuscaloosa
# Processing Record 9 of Set 3 | batagay-alyta
# Processing Record 10 of Set 3 | asau
# Processing Record 11 of Set 3 | kutum
# Processing Record 12 of Set 3 | sinnamary
# Processing Record 13 of Set 3 | san quintin
# Processing Record 14 of Set 3 | tuatapere
# Processing Record 15 of Set 3 | tasiilaq
# Processing Record 16 of Set 3 | torbay
# Processing Record 17 of Set 3 | laguna
# Processing Record 18 of Set 3 | coahuayana
# Processing Record 19 of Set 3 | new norfolk
# Processing Record 20 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 3 | khatanga
# Processing Record 22 of Set 3 | victoria
# Processing Record 23 of Set 3 | svetlyy
# Processing Record 24 of Set 3 | ballina
# Processing Record 25 of Set 3 | aswan
# Processing Record 26 of Set 3 | lagoa
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 3 | port arthur
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | scarborough
# Processing Record 32 of Set 3 | kodiak
# Processing Record 33 of Set 3 | konevo
# Processing Record 34 of Set 3 | alice springs
# Processing Record 35 of Set 3 | muroto
# Processing Record 36 of Set 3 | airai
# Processing Record 37 of Set 3 | srandakan
# Processing Record 38 of Set 3 | hofn
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 3 | ciro marina
# Processing Record 42 of Set 3 | eagle pass
# Processing Record 43 of Set 3 | darhan
# Processing Record 44 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 3 | natal
# Processing Record 46 of Set 3 | aklavik
# Processing Record 47 of Set 3 | hobyo
# Processing Record 48 of Set 3 | iqaluit
# Processing Record 49 of Set 3 | elat
# Processing Record 0 of Set 4 | bredasdorp
# Processing Record 1 of Set 4 | japura
# Processing Record 2 of Set 4 | leshukonskoye
# Processing Record 3 of Set 4 | sao filipe
# Processing Record 4 of Set 4 | palmer
# Processing Record 5 of Set 4 | xiaoshi
# Processing Record 6 of Set 4 | cidreira
# Processing Record 7 of Set 4 | patiya
# Processing Record 8 of Set 4 | kysyl-syr
# Processing Record 9 of Set 4 | turukhansk
# Processing Record 10 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 4 | dikson
# Processing Record 12 of Set 4 | farah
# Processing Record 13 of Set 4 | oyama
# Processing Record 14 of Set 4 | sovetskaya gavan
# Processing Record 15 of Set 4 | nanzhang
# Processing Record 16 of Set 4 | steamboat springs
# Processing Record 17 of Set 4 | faanui
# Processing Record 18 of Set 4 | burnie
# Processing Record 19 of Set 4 | ilulissat
# Processing Record 20 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 4 | port alfred
# Processing Record 22 of Set 4 | lamu
# Processing Record 23 of Set 4 | lavrentiya
# Processing Record 24 of Set 4 | igrim
# Processing Record 25 of Set 4 | saint-georges
# Processing Record 26 of Set 4 | yellowknife
# Processing Record 27 of Set 4 | ucluelet
# Processing Record 28 of Set 4 | ribeira grande
# Processing Record 29 of Set 4 | saint george
# Processing Record 30 of Set 4 | iquique
# Processing Record 31 of Set 4 | castro
# Processing Record 32 of Set 4 | ebnat-kappel
# Processing Record 33 of Set 4 | singaraja
# Processing Record 34 of Set 4 | ullapool
# Processing Record 35 of Set 4 | saskylakh
# Processing Record 36 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 4 | chernyshevskiy
# Processing Record 38 of Set 4 | east london
# Processing Record 39 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 4 | jeremie
# Processing Record 41 of Set 4 | ancud
# Processing Record 42 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 43 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 4 | pacific grove
# Processing Record 45 of Set 4 | masuguru
# Processing Record 46 of Set 4 | singleton
# Processing Record 47 of Set 4 | esperance
# Processing Record 48 of Set 4 | belmonte
# Processing Record 49 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 0 of Set 5 | spornoye
# Processing Record 1 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 5 | severnoye
# Processing Record 3 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 5 | komsomolskiy
# Processing Record 5 of Set 5 | innisfail
# Processing Record 6 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 5 | tiarei
# Processing Record 8 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 9 of Set 5 | tuktoyaktuk
# Processing Record 10 of Set 5 | pevek
# Processing Record 11 of Set 5 | neka
# Processing Record 12 of Set 5 | itarema
# Processing Record 13 of Set 5 | sorland
# Processing Record 14 of Set 5 | pasighat
# Processing Record 15 of Set 5 | clyde river
# Processing Record 16 of Set 5 | nanortalik
# Processing Record 17 of Set 5 | adet
# Processing Record 18 of Set 5 | olutanga
# Processing Record 19 of Set 5 | jalu
# Processing Record 20 of Set 5 | ausa
# Processing Record 21 of Set 5 | zhezkazgan
# Processing Record 22 of Set 5 | ponta do sol
# Processing Record 23 of Set 5 | yulara
# Processing Record 24 of Set 5 | samaro
# Processing Record 25 of Set 5 | port keats
# Processing Record 26 of Set 5 | la ronge
# Processing Record 27 of Set 5 | broken hill
# Processing Record 28 of Set 5 | oranjemund
# Processing Record 29 of Set 5 | marsa matruh
# Processing Record 30 of Set 5 | nipawin
# Processing Record 31 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 5 | avarua
# Processing Record 33 of Set 5 | smidovich
# Processing Record 34 of Set 5 | vila franca do campo
# Processing Record 35 of Set 5 | kamiiso
# Processing Record 36 of Set 5 | coolum beach
# Processing Record 37 of Set 5 | darnah
# Processing Record 38 of Set 5 | zeya
# Processing Record 39 of Set 5 | longyearbyen
# Processing Record 40 of Set 5 | kijang
# Processing Record 41 of Set 5 | salym
# Processing Record 42 of Set 5 | yar-sale
# Processing Record 43 of Set 5 | imeni poliny osipenko
# Processing Record 44 of Set 5 | te anau
# Processing Record 45 of Set 5 | port lincoln
# Processing Record 46 of Set 5 | leningradskiy
# Processing Record 47 of Set 5 | giehun
# Processing Record 48 of Set 5 | posse
# Processing Record 49 of Set 5 | goderich
# Processing Record 0 of Set 6 | hirara
# Processing Record 1 of Set 6 | bubaque
# Processing Record 2 of Set 6 | labuhan
# Processing Record 3 of Set 6 | barrow
# Processing Record 4 of Set 6 | mayo
# Processing Record 5 of Set 6 | zemio
# Processing Record 6 of Set 6 | ostersund
# Processing Record 7 of Set 6 | sirnak
# Processing Record 8 of Set 6 | saint-philippe
# Processing Record 9 of Set 6 | barreiras
# Processing Record 10 of Set 6 | sitka
# Processing Record 11 of Set 6 | riwaka
# Processing Record 12 of Set 6 | koslan
# Processing Record 13 of Set 6 | lata
# Processing Record 14 of Set 6 | ko samui
# Processing Record 15 of Set 6 | vaitape
# Processing Record 16 of Set 6 | cairns
# Processing Record 17 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 6 | kruisfontein
# Processing Record 19 of Set 6 | hami
# Processing Record 20 of Set 6 | abha
# Processing Record 21 of Set 6 | westport
# Processing Record 22 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 6 | cascais
# Processing Record 24 of Set 6 | kerchevskiy
# Processing Record 25 of Set 6 | luau
# Processing Record 26 of Set 6 | hasaki
# Processing Record 27 of Set 6 | kavieng
# Processing Record 28 of Set 6 | casimiro castillo
# Processing Record 29 of Set 6 | fairbanks
# Processing Record 30 of Set 6 | bonthe
# Processing Record 31 of Set 6 | imbituva
# Processing Record 32 of Set 6 | ust-tsilma
# Processing Record 33 of Set 6 | maarianhamina
# Processing Record 34 of Set 6 | inuvik
# Processing Record 35 of Set 6 | luanda
# Processing Record 36 of Set 6 | pozo colorado
# Processing Record 37 of Set 6 | huanren
# Processing Record 38 of Set 6 | tefe
# Processing Record 39 of Set 6 | manaure
# Processing Record 40 of Set 6 | sao joao da barra
# Processing Record 41 of Set 6 | pagudpud
# Processing Record 42 of Set 6 | alasehir
# Processing Record 43 of Set 6 | rio gallegos
# Processing Record 44 of Set 6 | kahului
# Processing Record 45 of Set 6 | bathsheba
# Processing Record 46 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 6 | solnechnyy
# Processing Record 48 of Set 6 | uusikaupunki
# Processing Record 49 of Set 6 | pangai
# Processing Record 0 of Set 7 | yanam
# Processing Record 1 of Set 7 | port elizabeth
# Processing Record 2 of Set 7 | takoradi
# Processing Record 3 of Set 7 | quang ngai
# Processing Record 4 of Set 7 | anadyr
# Processing Record 5 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 7 | charters towers
# Processing Record 8 of Set 7 | margate
# Processing Record 9 of Set 7 | kununurra
# Processing Record 10 of Set 7 | puerto narino
# Processing Record 11 of Set 7 | carutapera
# Processing Record 12 of Set 7 | destin
# Processing Record 13 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 14 of Set 7 | lucea
# Processing Record 15 of Set 7 | talara
# Processing Record 16 of Set 7 | cabo san lucas
# Processing Record 17 of Set 7 | bolshaya dzhalga
# Processing Record 18 of Set 7 | srednekolymsk
# Processing Record 19 of Set 7 | luderitz
# Processing Record 20 of Set 7 | broome
# Processing Record 21 of Set 7 | rantepao
# Processing Record 22 of Set 7 | lazurne
# Processing Record 23 of Set 7 | namibe
# Processing Record 24 of Set 7 | kloulklubed
# Processing Record 25 of Set 7 | karratha
# Processing Record 26 of Set 7 | cooma
# Processing Record 27 of Set 7 | myrtle beach
# Processing Record 28 of Set 7 | port hedland
# Processing Record 29 of Set 7 | bacolod
# Processing Record 30 of Set 7 | usinsk
# Processing Record 31 of Set 7 | wadi maliz
# Processing Record 32 of Set 7 | lohja
# Processing Record 33 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 7 | foz
# Processing Record 35 of Set 7 | narasapur
# Processing Record 36 of Set 7 | yuryevets
# Processing Record 37 of Set 7 | khor
# Processing Record 38 of Set 7 | khairagarh
# Processing Record 39 of Set 7 | nemuro
# Processing Record 40 of Set 7 | lugovoy
# Processing Record 41 of Set 7 | heihe
# Processing Record 42 of Set 7 | mbeya
# Processing Record 43 of Set 7 | san patricio
# Processing Record 44 of Set 7 | mayor pablo lagerenza
# Processing Record 45 of Set 7 | olinda
# Processing Record 46 of Set 7 | jimenez
# Processing Record 47 of Set 7 | udachnyy
# Processing Record 48 of Set 7 | victor harbor
# Processing Record 49 of Set 7 | lakatoro
# Processing Record 0 of Set 8 | bremerton
# Processing Record 1 of Set 8 | tommot
# Processing Record 2 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 8 | saint anthony
# Processing Record 4 of Set 8 | varhaug
# Processing Record 5 of Set 8 | pochutla
# Processing Record 6 of Set 8 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 7 of Set 8 | severo-kurilsk
# Processing Record 8 of Set 8 | richards bay
# Processing Record 9 of Set 8 | oistins
# Processing Record 10 of Set 8 | terrace
# Processing Record 11 of Set 8 | talovaya
# Processing Record 12 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 13 of Set 8 | iralaya
# Processing Record 14 of Set 8 | barabai
# Processing Record 15 of Set 8 | ust-nera
# Processing Record 16 of Set 8 | gwadar
# Processing Record 17 of Set 8 | mayskiy
# Processing Record 18 of Set 8 | maykain
# City not found. Skipping...
# Processing Record 19 of Set 8 | kendal
# Processing Record 20 of Set 8 | abu zabad
# Processing Record 21 of Set 8 | banjar
# Processing Record 22 of Set 8 | kytlym
# City not found. Skipping...
# Processing Record 23 of Set 8 | semirom
# Processing Record 24 of Set 8 | ovre ardal
# Processing Record 25 of Set 8 | hirado
# Processing Record 26 of Set 8 | college
# Processing Record 27 of Set 8 | diamantino
# Processing Record 28 of Set 8 | penzance
# Processing Record 29 of Set 8 | kieta
# Processing Record 30 of Set 8 | tual
# Processing Record 31 of Set 8 | mantua
# Processing Record 32 of Set 8 | pochinki
# Processing Record 33 of Set 8 | ternate
# Processing Record 34 of Set 8 | klaksvik
# Processing Record 35 of Set 8 | izumo
# Processing Record 36 of Set 8 | bangui
# Processing Record 37 of Set 8 | provideniya
# Processing Record 38 of Set 8 | fortuna
# Processing Record 39 of Set 8 | ust-omchug
# Processing Record 40 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 41 of Set 8 | limbang
# Processing Record 42 of Set 8 | mogadishu
# Processing Record 43 of Set 8 | biak
# Processing Record 44 of Set 8 | chuy
# Processing Record 45 of Set 8 | polohy
# Processing Record 46 of Set 8 | ayabe
# Processing Record 47 of Set 8 | ostrovnoy
# Processing Record 48 of Set 8 | shitanjing
# Processing Record 49 of Set 8 | san martin
# Processing Record 0 of Set 9 | anito
# Processing Record 1 of Set 9 | bahir dar
# Processing Record 2 of Set 9 | mount isa
# Processing Record 3 of Set 9 | araouane
# Processing Record 4 of Set 9 | talnakh
# Processing Record 5 of Set 9 | bom jesus
# Processing Record 6 of Set 9 | tahta
# Processing Record 7 of Set 9 | lakes entrance
# Processing Record 8 of Set 9 | ibra
# Processing Record 9 of Set 9 | mamallapuram
# Processing Record 10 of Set 9 | coos bay
# Processing Record 11 of Set 9 | narsaq
# Processing Record 12 of Set 9 | bilibino
# Processing Record 13 of Set 9 | filadelfia
# Processing Record 14 of Set 9 | aloleng
# Processing Record 15 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 16 of Set 9 | kautokeino
# Processing Record 17 of Set 9 | shellbrook
# Processing Record 18 of Set 9 | antsohihy
# Processing Record 19 of Set 9 | kampong thum
# Processing Record 20 of Set 9 | niksar
# Processing Record 21 of Set 9 | omsukchan
# Processing Record 22 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 9 | auki
# Processing Record 24 of Set 9 | requena
# Processing Record 25 of Set 9 | zabol
# Processing Record 26 of Set 9 | chippewa falls
# Processing Record 27 of Set 9 | kindersley
# Processing Record 28 of Set 9 | sambek
# Processing Record 29 of Set 9 | bima
# Processing Record 30 of Set 9 | vallenar
# Processing Record 31 of Set 9 | vostok
# Processing Record 32 of Set 9 | kushiro
# Processing Record 33 of Set 9 | ubajara
# Processing Record 34 of Set 9 | dudinka
# Processing Record 35 of Set 9 | umm kaddadah
# Processing Record 36 of Set 9 | port augusta
# Processing Record 37 of Set 9 | borova
# Processing Record 38 of Set 9 | sipe sipe
# Processing Record 39 of Set 9 | adrar
# Processing Record 40 of Set 9 | port hardy
# Processing Record 41 of Set 9 | sochi
# Processing Record 42 of Set 9 | ahipara
# Processing Record 43 of Set 9 | oskarshamn
# Processing Record 44 of Set 9 | half moon bay
# Processing Record 45 of Set 9 | naze
# Processing Record 46 of Set 9 | melnikovo
# Processing Record 47 of Set 9 | yumen
# Processing Record 48 of Set 9 | suntar
# Processing Record 49 of Set 9 | paralimni
# Processing Record 0 of Set 10 | birao
# Processing Record 1 of Set 10 | izhma
# Processing Record 2 of Set 10 | togur
# Processing Record 3 of Set 10 | manggar
# Processing Record 4 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 5 of Set 10 | neiafu
# Processing Record 6 of Set 10 | sebrovo
# Processing Record 7 of Set 10 | marawi
# Processing Record 8 of Set 10 | antofagasta
# Processing Record 9 of Set 10 | dongsheng
# Processing Record 10 of Set 10 | the valley
# Processing Record 11 of Set 10 | andenes
# Processing Record 12 of Set 10 | muros
# Processing Record 13 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 10 | axim
# Processing Record 15 of Set 10 | basco
# Processing Record 16 of Set 10 | churapcha
# Processing Record 17 of Set 10 | tuxpan
# Processing Record 18 of Set 10 | litovko
# Processing Record 19 of Set 10 | grand gaube
# Processing Record 20 of Set 10 | gladstone
# Processing Record 21 of Set 10 | mahibadhoo
# Processing Record 22 of Set 10 | pundaguitan
# Processing Record 23 of Set 10 | shubarkuduk
# Processing Record 24 of Set 10 | nome
# Processing Record 25 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 10 | balykshi
# Processing Record 27 of Set 10 | mehran
# Processing Record 28 of Set 10 | povazska bystrica
# Processing Record 29 of Set 10 | nambucca heads
# Processing Record 30 of Set 10 | naryan-mar
# Processing Record 31 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 10 | santo antonio da platina
# Processing Record 33 of Set 10 | agnibilekrou
# Processing Record 34 of Set 10 | mount gambier
# Processing Record 35 of Set 10 | russell
# Processing Record 36 of Set 10 | kismayo
# Processing Record 37 of Set 10 | huarmey
# Processing Record 38 of Set 10 | kostek
# Processing Record 39 of Set 10 | yarada
# Processing Record 40 of Set 10 | caiaponia
# Processing Record 41 of Set 10 | lima
# Processing Record 42 of Set 10 | sarkand
# Processing Record 43 of Set 10 | mayya
# Processing Record 44 of Set 10 | praxedis guerrero
# Processing Record 45 of Set 10 | kearney
# Processing Record 46 of Set 10 | havelock
# Processing Record 47 of Set 10 | det udom
# Processing Record 48 of Set 10 | charagua
# Processing Record 49 of Set 10 | bredy
# Processing Record 0 of Set 11 | ust-kuyga
# Processing Record 1 of Set 11 | vao
# Processing Record 2 of Set 11 | ust-maya
# Processing Record 3 of Set 11 | guararapes
# Processing Record 4 of Set 11 | mbala
# Processing Record 5 of Set 11 | warmbad
# Processing Record 6 of Set 11 | birjand
# Processing Record 7 of Set 11 | lakselv
# Processing Record 8 of Set 11 | havre-saint-pierre
# Processing Record 9 of Set 11 | miri
# Processing Record 10 of Set 11 | manokwari
# Processing Record 11 of Set 11 | ulladulla
# Processing Record 12 of Set 11 | sovetskiy
# Processing Record 13 of Set 11 | salinopolis
# Processing Record 14 of Set 11 | gorontalo
# Processing Record 15 of Set 11 | great falls
# Processing Record 16 of Set 11 | mrakovo
# Processing Record 17 of Set 11 | ponta delgada
# Processing Record 18 of Set 11 | makinsk
# Processing Record 19 of Set 11 | tosya
# Processing Record 20 of Set 11 | pandan
# Processing Record 21 of Set 11 | praya
# Processing Record 22 of Set 11 | garissa
# Processing Record 23 of Set 11 | negombo
# Processing Record 24 of Set 11 | tynda
# Processing Record 25 of Set 11 | mehamn
# Processing Record 26 of Set 11 | flinders
# Processing Record 27 of Set 11 | atocha
# Processing Record 28 of Set 11 | ajdabiya
# Processing Record 29 of Set 11 | hervey bay
# Processing Record 30 of Set 11 | laukaa
# Processing Record 31 of Set 11 | baruun-urt
# Processing Record 32 of Set 11 | madaoua
# Processing Record 33 of Set 11 | keflavik
# Processing Record 34 of Set 11 | cayenne
# Processing Record 35 of Set 11 | melita
# Processing Record 36 of Set 11 | ledyard
# Processing Record 37 of Set 11 | dwarka
# Processing Record 38 of Set 11 | reo
# Processing Record 39 of Set 11 | saurimo
# Processing Record 40 of Set 11 | ndungu
# Processing Record 41 of Set 11 | moose factory
# Processing Record 42 of Set 11 | buala
# Processing Record 43 of Set 11 | cabedelo
# Processing Record 44 of Set 11 | katsuura
# Processing Record 45 of Set 11 | sosnovo-ozerskoye
# Processing Record 46 of Set 11 | moyobamba
# Processing Record 47 of Set 11 | christchurch
# Processing Record 48 of Set 11 | punta cardon
# Processing Record 49 of Set 11 | matamoros
# Processing Record 0 of Set 12 | mecca
# Processing Record 1 of Set 12 | ayan
# Processing Record 2 of Set 12 | bo rai
# Processing Record 3 of Set 12 | thurso
# Processing Record 4 of Set 12 | kamaishi
# Processing Record 5 of Set 12 | ugoofaaru
# Processing Record 6 of Set 12 | cedar city
# Processing Record 7 of Set 12 | liverpool
# Processing Record 8 of Set 12 | zheleznodorozhnyy
# Processing Record 9 of Set 12 | pudozh
# Processing Record 10 of Set 12 | san rafael
# Processing Record 11 of Set 12 | bara
# Processing Record 12 of Set 12 | teguldet
# Processing Record 13 of Set 12 | shingu
# Processing Record 14 of Set 12 | puerto madero
# Processing Record 15 of Set 12 | gizo
# Processing Record 16 of Set 12 | yining
# Processing Record 17 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 12 | tarakan
# Processing Record 19 of Set 12 | viedma
# Processing Record 20 of Set 12 | leo
# Processing Record 21 of Set 12 | sur
# Processing Record 22 of Set 12 | souillac
# Processing Record 23 of Set 12 | porto novo
# Processing Record 24 of Set 12 | trairi
# Processing Record 25 of Set 12 | harlingen
# Processing Record 26 of Set 12 | isangel
# Processing Record 27 of Set 12 | yadgir
# Processing Record 28 of Set 12 | san cristobal
# Processing Record 29 of Set 12 | faya
# Processing Record 30 of Set 12 | pemba
# Processing Record 31 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 32 of Set 12 | emba
# Processing Record 33 of Set 12 | lere
# Processing Record 34 of Set 12 | road town
# Processing Record 35 of Set 12 | venado tuerto
# Processing Record 36 of Set 12 | mpika
# Processing Record 37 of Set 12 | la gomera
# Processing Record 38 of Set 12 | buraydah
# Processing Record 39 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 12 | harper
# Processing Record 41 of Set 12 | utiel
# Processing Record 42 of Set 12 | basoko
# Processing Record 43 of Set 12 | la macarena
# Processing Record 44 of Set 12 | yuncheng
# Processing Record 45 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 12 | ranfurly
# Processing Record 47 of Set 12 | alofi
# Processing Record 48 of Set 12 | barnala
# Processing Record 49 of Set 12 | hamilton
# Processing Record 0 of Set 13 | san ramon
# Processing Record 1 of Set 13 | wanaka
# Processing Record 2 of Set 13 | pangnirtung
# Processing Record 3 of Set 13 | meulaboh
# Processing Record 4 of Set 13 | tromso
# Processing Record 5 of Set 13 | vung tau
# Processing Record 6 of Set 13 | bestobe
# Processing Record 7 of Set 13 | ketchikan
# Processing Record 8 of Set 13 | matagami
# Processing Record 9 of Set 13 | gonen
# Processing Record 10 of Set 13 | villazon
# Processing Record 11 of Set 13 | rocha
# Processing Record 12 of Set 13 | saint-honore
# Processing Record 13 of Set 13 | homer
# Processing Record 14 of Set 13 | tiksi
# Processing Record 15 of Set 13 | abaete
# Processing Record 16 of Set 13 | dunedin
# Processing Record 17 of Set 13 | grindavik
# Processing Record 18 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 13 | cortez
# Processing Record 20 of Set 13 | netanya
# Processing Record 21 of Set 13 | kilindoni
# Processing Record 22 of Set 13 | lasa
# Processing Record 23 of Set 13 | vrangel
# Processing Record 24 of Set 13 | najran
# Processing Record 25 of Set 13 | korostyshiv
# Processing Record 26 of Set 13 | kombissiri
# Processing Record 27 of Set 13 | daigo
# Processing Record 28 of Set 13 | quatre cocos
# Processing Record 29 of Set 13 | prokuplje
# Processing Record 30 of Set 13 | port blair
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          580
# Lat           580
# Lng           580
# Max Temp      580
# Humidity      580
# Cloudiness    580
# Wind Speed    580
# Country       580
# Date          580
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        punta arenas -53.1500  -70.9167     13.06        47          75
# 1         bandarbeyla   9.4942   50.8122     24.55        73           7
# 2          georgetown   5.4112  100.3354     27.96        89          20
# 3             rikitea -23.1203 -134.9692     26.27        65          83
# 4          chokurdakh  70.6333  147.9167    -40.79        98          99
#
#          Wind Speed Country        Date
# City_ID
# 0              6.69      CL  1676141198
# 1              8.36      SO  1676141198
# 2              1.54      MY  1676141112
# 3              6.34      PF  1676141199
# 4              1.48      RU  1676140906

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        punta arenas -53.1500  -70.9167     13.06        47          75
# 1         bandarbeyla   9.4942   50.8122     24.55        73           7
# 2          georgetown   5.4112  100.3354     27.96        89          20
# 3             rikitea -23.1203 -134.9692     26.27        65          83
# 4          chokurdakh  70.6333  147.9167    -40.79        98          99
#
#          Wind Speed Country        Date
# City_ID
# 0              6.69      CL  1676141198
# 1              8.36      SO  1676141198
# 2              1.54      MY  1676141112
# 3              6.34      PF  1676141199
# 4              1.48      RU  1676140906

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
import time 
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],
            city_data_df["Max Temp"],
            edgecolor = "red",
            linewidths=1,
            marker="o",
            alpha= 0.8,
            label="Cities")

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Max Latitude vs. Temperature ({date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"],
            city_data_df["Humidity"],
            edgecolor = "green",
            linewidths=1,
            marker="o",
            alpha= 0.8,
            label="Cities")

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Max Latitude vs. Humidity ({date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],
            city_data_df["Cloudiness"],
            edgecolor = "orange",
            linewidths=1,
            marker="o",
            alpha= 0.8,
            label="Cities")

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Max Latitude vs. Cloudiness ({date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],
            city_data_df["Wind Speed"],
            edgecolor = "blue",
            linewidths=1,
            marker="o",
            alpha= 0.8,
            label="Cities")

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (%)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_value, y_value, title, text_coord):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_value = x_value * slope + intercept
    line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
    
    plt.scatter(x_value, y_value)
    plt.plot(x_value, regress_value, "r-")
    plt.annotate(line_eq, text_coord, fontsize=15, color="red")
    plt.xlabel("Lat")
    plt.ylabel(title)
    print(f"The r-value is {rvalue ** 2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df[city_data_df["Lat"]>0]
# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        bandarbeyla   9.4942   50.8122     24.55        73           7
# 2         georgetown   5.4112  100.3354     27.96        89          20
# 4         chokurdakh  70.6333  147.9167    -40.79        98          99
# 6           sobolevo  54.4299   31.8996      0.54        97         100
# 7             ixtapa  20.7000 -105.2000     24.57        61          20
#
#          Wind Speed Country        Date
# City_ID
# 1              8.36      SO  1676141198
# 2              1.54      MY  1676141112
# 4              1.48      RU  1676140906
# 6              7.76      RU  1676141200
# 7              4.12      MX  1676141200

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        punta arenas -53.1500  -70.9167     13.06        47          75
# 3             rikitea -23.1203 -134.9692     26.27        65          83
# 5            hermanus -34.4187   19.2345     20.45        83           0
# 13              vaini -21.2000 -175.2000     25.09       100          75
# 14              bluff -46.6000  168.3333     12.10        89         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.69      CL  1676141198
# 3              6.34      PF  1676141199
# 5              2.73      ZA  1676141199
# 13             1.54      TO  1676141202
# 14             2.38      NZ  1676141202

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values =northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (6, -10))
# Out:
# The r-value is 0.7523995278272214

# %%
# Linear regression on Southern Hemisphere
x_values =southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-50, 20))
# Out:
# The r-value is 0.2591881941806064

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values =northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (50, 10))
# Out:
# The r-value is 0.2138586751839671

# %%
# Southern Hemisphere
x_values =northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (50, 20))
# Out:
# The r-value is 0.2138586751839671

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values =northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloundiness", (40, 20))
# Out:
# The r-value is 0.08555874883559982

# %%
# Southern Hemisphere
x_values =southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloundiness", (-50, 25))
# Out:
# The r-value is 0.07724172305448698

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values =northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (10, 15))
# Out:
# The r-value is 0.0013142336095172669

# %%
# Southern Hemisphere
x_values =southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-50, 10))
# Out:
# The r-value is 0.002600347242361113

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
